# %% [markdown]
# ## Assignment

# %% [markdown]
# Import necessary library

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %% [markdown]
# Read the data

# %%
df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2)

# %% [markdown]
# Drop unnecessary columns

# %%
# in pandas axis=0 represents rows (default) and axis=1 represents columns.
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)
df_can.head(2)
# Out:
#         OdName AreaName          RegName  ...  2011  2012  2013
# 0  Afghanistan     Asia    Southern Asia  ...  2203  2635  2004
# 1      Albania   Europe  Southern Europe  ...   539   620   603
#
# [2 rows x 38 columns]

# %%
df_can
# Out:
#              OdName AreaName             RegName  ...  2011  2012  2013
# 0       Afghanistan     Asia       Southern Asia  ...  2203  2635  2004
# 1           Albania   Europe     Southern Europe  ...   539   620   603
# 2           Algeria   Africa     Northern Africa  ...  4325  3774  4331
# 3    American Samoa  Oceania           Polynesia  ...     0     0     0
# 4           Andorra   Europe     Southern Europe  ...     0     1     1
# ..              ...      ...                 ...  ...   ...   ...   ...
# 190        Viet Nam     Asia  South-Eastern Asia  ...  1723  1731  2112
# 191  Western Sahara   Africa     Northern Africa  ...     0     0     0
# 192           Yemen     Asia        Western Asia  ...   160   174   217
# 193          Zambia   Africa      Eastern Africa  ...    69    46    59
# 194        Zimbabwe   Africa      Eastern Africa  ...   434   437   407
#
# [195 rows x 38 columns]

# %% [markdown]
# Rename columns title

# %%
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can.columns
# Out:
# Index([  'Country', 'Continent',    'Region',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %% [markdown]
# Add a 'Total' column

# %%
df_can
# Out:
#             Country Continent              Region  ...  2011  2012  2013
# 0       Afghanistan      Asia       Southern Asia  ...  2203  2635  2004
# 1           Albania    Europe     Southern Europe  ...   539   620   603
# 2           Algeria    Africa     Northern Africa  ...  4325  3774  4331
# 3    American Samoa   Oceania           Polynesia  ...     0     0     0
# 4           Andorra    Europe     Southern Europe  ...     0     1     1
# ..              ...       ...                 ...  ...   ...   ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  ...  1723  1731  2112
# 191  Western Sahara    Africa     Northern Africa  ...     0     0     0
# 192           Yemen      Asia        Western Asia  ...   160   174   217
# 193          Zambia    Africa      Eastern Africa  ...    69    46    59
# 194        Zimbabwe    Africa      Eastern Africa  ...   434   437   407
#
# [195 rows x 38 columns]

# %%
df_can['Total'] = df_can.sum(axis=1)

# %% [markdown]
# **Question 1:** Let's compare the number of immigrants from India and China from 1980 to 2013.

# %% [markdown]
# Step 1: Get the data set for China and India, and display dataframe.

# %%
import matplotlib.pyplot as plt

# %%
# Rahma Fadhila Moenggah - 1301180050
### type your answer here
df_can.set_index('Country', inplace=True)

# %%
years = list(range(1980, 2014))
years
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %%
df_IC = df_can.loc[['India','China'], years].transpose()

#Display dataframe
df_IC
# Out:
# Country  India  China
# 1980      8880   5123
# 1981      8670   6682
# 1982      8147   3308
# 1983      7338   1863
# 1984      5704   1527
# 1985      4211   1816
# 1986      7150   1960
# 1987     10189   2643
# 1988     11522   2758
# 1989     10343   4323
# 1990     12041   8076
# 1991     13734  14255
# 1992     13673  10846
# 1993     21496   9817
# 1994     18620  13128
# 1995     18489  14398
# 1996     23859  19415
# 1997     22268  20475
# 1998     17241  21049
# 1999     18974  30069
# 2000     28572  35529
# 2001     31223  36434
# 2002     31889  31961
# 2003     27155  36439
# 2004     28235  36619
# 2005     36210  42584
# 2006     33848  33518
# 2007     28742  27642
# 2008     28261  30037
# 2009     29456  29622
# 2010     34235  30391
# 2011     27509  28502
# 2012     30933  33024
# 2013     33087  34129

# %% [markdown]
# Step 2: Plot graph. We will explicitly specify line plot by passing in `kind` parameter to `plot()`.

# %%
# Rahma Fadhila Moenggah - 1301180050
### type your answer here
df_IC.plot(kind='line', figsize=(10, 6), color=['cornflowerblue', 'turquoise'])

plt.title('Immigrants from India and China from 1980 to 2013')
plt.xlabel('Years')
plt.ylabel('The Number of Immigrants')
plt.show()

# %% [markdown]
# **Question 2:** Compare the trend of top 5 countries that contributed the most to immigration to Canada.

# %%
# Rahma Fadhila Moenggah - 1301180050
### type your answer here
df_can.sort_values(by='Total', ascending=False, axis=0, inplace=True)
df_top = df_can.head(5)
df_top = df_top[years].transpose()
df_top
# Out:
# Country  India  China  ...  Philippines  Pakistan
# 1980      8880   5123  ...         6051       978
# 1981      8670   6682  ...         5921       972
# 1982      8147   3308  ...         5249      1201
# 1983      7338   1863  ...         4562       900
# 1984      5704   1527  ...         3801       668
# 1985      4211   1816  ...         3150       514
# 1986      7150   1960  ...         4166       691
# 1987     10189   2643  ...         7360      1072
# 1988     11522   2758  ...         8639      1334
# 1989     10343   4323  ...        11865      2261
# 1990     12041   8076  ...        12509      2470
# 1991     13734  14255  ...        12718      3079
# 1992     13673  10846  ...        13670      4071
# 1993     21496   9817  ...        20479      4777
# 1994     18620  13128  ...        19532      4666
# 1995     18489  14398  ...        15864      4994
# 1996     23859  19415  ...        13692      9125
# 1997     22268  20475  ...        11549     13073
# ...

# %%
### type your answer here
df_top.plot(kind='area', figsize=(15, 7), color=['cornflowerblue', 'turquoise', 'lightsteelblue', 'palevioletred', 'orange'])

plt.title('5 Countries that Contributed the Most to Immigration to Canada')
plt.xlabel('Years')
plt.ylabel('The Number of Immigrants')
plt.show()

# %% [markdown]
# **Question 3**: Create an unstacked area plot of the 5 countries that contributed the least to immigration to Canada **from** 1980 to 2013. Use a transparency value of 0.55.

# %%
# Rahma Fadhila Moenggah - 1301180050
### type your answer here
df_can.sort_values(['Total'], ascending = True, axis=0, inplace = True)
df_least = df_can.head()

df_least = df_least[years].transpose()
df_least.head(5)
# Out:
# Country  Palau  Western Sahara  Marshall Islands  New Caledonia  San Marino
# 1980         0               0                 0              0           1
# 1981         0               0                 0              0           0
# 1982         0               0                 0              0           0
# 1983         0               0                 0              0           0
# 1984         0               0                 0              0           0

# %%
ax = df_least.plot(kind='area', stacked=False, alpha=0.55, figsize=(10, 6), color=['cornflowerblue', 'turquoise', 'lightsteelblue', 'palevioletred', 'orange'])
ax.set_title('5 Countries that Contributed the Least to Immigration to Canada')
ax.set_xlabel('Years')
ax.set_ylabel('The Number of Immigrants')
# Out:
# Text(0, 0.5, 'The Number of Immigrants')

# %% [markdown]
# **Question 4**: Display the immigration distribution for Greece, Albania, and Bulgaria for years 1980 - 2013? Use an overlapping plot with 15 bins and a transparency value of 0.35.

# %%
# Rahma Fadhila Moenggah - 1301180050
### type your answer here
df_GAB = df_can.loc[['Greece', 'Albania', 'Bulgaria'], years].transpose()
count, bin_edges = np.histogram(df_GAB, 15)

df_GAB.plot(kind ='hist', bins=15, alpha=0.35, xticks=bin_edges, figsize=(10, 6), color=['cornflowerblue', 'turquoise', 'lightcoral'])

plt.title('The Immigration Distribution for Greece, Albania, and Bulgaria for Years 1980 - 2013')
plt.xlabel('The Number of Immigrants')
plt.ylabel('Years')
plt.show()

# %% [markdown]
# **Question 5:** Create a *horizontal* bar plot showing the *total* number of immigrants to Canada from the top 15 countries, for the period 1980 - 2013. Label each country with the total immigrant count.

# %% [markdown]
# Step 1: Get the data pertaining to the top 15 countries.

# %%
# Rahma Fadhila Moenggah - 1301180050
### type your answer here
df_can.sort_values(by='Total', ascending=True, inplace=True)

df_top15 = df_can['Total'].tail(15)
df_top15
# Out:
# Country
# Romania                                                  93585
# Viet Nam                                                 97146
# Jamaica                                                 106431
# France                                                  109091
# Lebanon                                                 115359
# Poland                                                  139241
# Republic of Korea                                       142581
# Sri Lanka                                               148358
# Iran (Islamic Republic of)                              175923
# United States of America                                241122
# Pakistan                                                241600
# Philippines                                             511391
# United Kingdom of Great Britain and Northern Ireland    551500
# China                                                   659962
# India                                                   691904
# ...

# %% [markdown]
# Step 2: Plot data:
#    1. Use `kind='barh'` to generate a bar chart with horizontal bars.
#    2. Make sure to choose a good size for the plot and to label your axes and to give the plot a title.
#    3. Loop through the countries and annotate the immigrant population using the anotate function of the scripting interface.

# %%
# Rahma Fadhila Moenggah - 1301180050
### type your answer here
df_top15.plot(kind='barh', figsize=(10, 11), color='midnightblue')
plt.xlabel('The Number of Immigrants')
plt.title('Number of Immigrants to Canada from the Top 15 Countries between 1980 - 2013')

for index, value in enumerate(df_top15):
  label = format(int(value), ',')
  plt.annotate(label, xy=(value - 47000, index - 0.1), color='white')

plt.show()

# %% [markdown]
# # Thank you for completing this lab!

# %% [markdown]
# <hr>
#
# Copyright &copy; 2019 [Cognitive Class](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
